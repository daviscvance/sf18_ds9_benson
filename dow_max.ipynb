# %%
import sys
import os

# %%
import pandas as pd

# %%
df = pd.read_csv("station_data.csv", index_col=0, header=0)

df.drop(labels='DATE_TIME', axis=1, inplace=True, errors='ignore')

df_tot = (
    df.groupby(['DAYS', 'STATION_LINE'])
    .sum()
    .reset_index()
    .sort_values(by='TOTAL_TRAFFIC', ascending=False)
    .set_index('DAYS', drop=True)
)

# %%
df_tot.loc['Monday', :].head(25)
# Out:
#                         STATION_LINE  TOTAL_TRAFFIC
# DAYS
# Monday                      23 ST CE       261982.0
# Monday       14 ST-UNION SQ 456LNQRW       203619.0
# Monday                     86 ST 456       202979.0
# Monday             LEXINGTON AV/63 F       200980.0
# Monday         B'WAY-LAFAYETTE BDFQ6       196807.0
# Monday      34 ST-HERALD SQ BDFMNQRW       192383.0
# Monday                 86 ST-2 AVE Q       191697.0
# Monday      ATL AV-BARCLAY 2345BDNQR       191277.0
# Monday                        1 AV L       190700.0
# Monday   TIMES SQ-42 ST ACENQRS1237W       187425.0
# Monday        W 4 ST-WASH SQ ABCDEFM       186249.0
# Monday                   GRAND ST BD       185722.0
# Monday  42 ST-PORT AUTH ACENQRS1237W       184687.0
# Monday         GRD CNTRL-42 ST 4567S       177665.0
# Monday         34 ST-PENN STA 123ACE       175895.0
# Monday                     YORK ST F       168418.0
# Monday             MYRTLE-WYCKOFF LM       161937.0
# Monday                     8 AV ACEL       160134.0
# Monday                 MYRTLE AV JMZ       157620.0
# Monday                 5 AV/53 ST EM       151123.0
# Monday                    125 ST 456       148851.0
# Monday                     72 ST 123       144325.0
# Monday                      167 ST 4       142968.0
# Monday                     36 ST DNR       142455.0
# Monday               JUNCTION BLVD 7       139524.0
